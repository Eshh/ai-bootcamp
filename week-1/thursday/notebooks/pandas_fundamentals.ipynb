# %%
import pandas as pd

# %%
# Series
from_list = pd.Series([1, 2, 3, 4, 5])

# %%
type(from_list)
# Out:
# pandas.core.series.Series

# %%
from_list = pd.Series([1, 2, 3, 4, 5], index=["a", "b", "c", "d", "e"])

# %%
from_list
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
from_dict = pd.Series({"x" : 100, "y" : 200})

# %%
from_dict
# Out:
# x    100
# y    200
# dtype: int64

# %%
s = pd.Series([10, 20, 30, 40, 50], index=["a", "b", "c", "d", "e"])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
original = s.to_dict()
original
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s.values.tolist()
# Out:
# [10, 20, 30, 40, 50]

# %%
s.index.to_list()
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
type(s.shape)
# Out:
# tuple

# %%
s.index.value_counts()
# Out:
# a    1
# b    1
# c    1
# d    1
# e    1
# Name: count, dtype: int64

# %%
from_dict = pd.DataFrame({
    "name" : ("I" , "N", "T"),
    "age": [25, 30, 35],
    "city": ["Vizag", "Hyd", "Bangalore"]}
)

# %%
from_dict.head(5)
# Out:
#   name  age       city
# 0    I   25      Vizag
# 1    N   30        Hyd
# 2    T   35  Bangalore

# %%
from_dict = pd.DataFrame([
    {"name": "Innocito", "age": 25, "city": "Vizag", "country": "India"},
    {"name": "K", "age": 25, "city": "Vizag", "country": "India"},
])

# %%
from_dict
# Out:
#        name  age   city country
# 0  Innocito   25  Vizag   India
# 1         K   25  Vizag   India

# %%
type(from_dict.name)
# Out:
# pandas.core.series.Series
