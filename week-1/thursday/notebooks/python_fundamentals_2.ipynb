# %%
# Dictionary

# %%
empty_dict = {}
empty_dict = dict()

# %%
len(empty_dict)
# Out:
# 0

# %%
type(dict)
# Out:
# type

# %%
simple_dict = {"name": "Innocito", "age":4}

# %%
simple_dict
# Out:
# {'name': 'Innocito', 'age': 4}

# %%
from_pairs = dict([("a", 1), ("b", 1)])

# %%
from_pairs
# Out:
# {'a': 1, 'b': 1}

# %%
from_pairs = dict([(("a"), 1), (("b"), 1)])

# %%
from_pairs
# Out:
# {'a': 1, 'b': 1}

# %%
from_pairs_2 = dict([(["a"], 1), (["b"], 1)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-501/2307370550.py in <cell line: 0>()
# ----> 1 from_pairs_2 = dict([(["a"], 1), (["b"], 1)])
#
# TypeError: unhashable type: 'list'

# %%
comprehension = {x: x**2 for x in range(1, 6)}

# %%
comprehension
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# Accesing the elements in a dictionary
company = {"name": "Innocito", "age": 25, "city": "Vizag"}

# %%
name = company["name"]

# %%
name
# Out:
# 'Innocito'

# %%
name = company["sur_name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-501/2951220002.py in <cell line: 0>()
# ----> 1 name = company["sur_name"]
#
# KeyError: 'sur_name'

# %%
name = company.get("name")

# %%
name
# Out:
# 'Innocito'

# %%
name = company.get("sur_name")

# %%
name

# %%
name = company.get("sur_name", "SURNAME NOT PRESENT")

# %%
company["age"] = 4

# %%
keys = list(company.keys())

# %%
keys
# Out:
# ['name', 'age', 'city']

# %%
values = list(company.values())

# %%
values
# Out:
# ['Innocito', 4, 'Vizag']

# %%
from_lists = {k:v for k, v in zip(keys, values)}

# %%
from_lists
# Out:
# {'name': 'Innocito', 'age': 4, 'city': 'Vizag'}

# %%
keys.append("sur_name")

# %%
from_lists = {k:v for k, v in zip(keys, values)}

# %%
from_lists
# Out:
# {'name': 'Innocito', 'age': 4, 'city': 'Vizag'}

# %%
swapped_dict = {v:k for k, v in zip(keys, values)}

# %%
swapped_dict
# Out:
# {'Innocito': 'name', 4: 'age', 'Vizag': 'city'}

# %%
# Shallow and deep copy

# %%
import copy
cloned_dict = copy.copy(swapped_dict)

# %%
id(swapped_dict)
# Out:
# 132012366549120

# %%
id(cloned_dict)
# Out:
# 132012362448960

# %%
cloned_dict_new = swapped_dict.copy()

# %%
cloned_dict_new
# Out:
# {'Innocito': 'name', 4: 'age', 'Vizag': 'city'}

# %%
deep_cloned_dict = copy.deepcopy(swapped_dict)

# %%
# Sets

# %%
set_a = {1, 2 , 3, 4, 5}

# %%
set_b = {4, 5, 6, 7, 8}

# %%
set_a = {1, 2 , 3, 4, 5, 5}

# %%
set_a
# Out:
# {1, 2, 3, 4, 5}

# %%
union_set = set_a | set_b  # set union
union_set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
intersection_set = set_a & set_b # set intersection
intersection_set
# Out:
# {4, 5}

# %%
diff_set = set_a - set_b # set difference
diff_set
# Out:
# {1, 2, 3}

# %%
#numberStart

# %%
#number_start

# %%
# When creating classses -  NumberStart -- can be used while creating classes

# %%
# For loops

# %%
sum_numbers = 0
for num in range(1,6):
  sum_numbers += num
sum_numbers
# Out:
# 15

# %%
for value in values:
  print(value)
# Out:
# Innocito
# 4
# Vizag

# %%
# Iterate with index
for i, value in enumerate(values):
  print(f"Index of {value} is {i}")
# Out:
# Index of Innocito is 0
# Index of 4 is 1
# Index of Vizag is 2

# %%
company = {"name": "Innocito", "age": 25, "city": "Vizag"}
for key, value in company.items():
  print(f"Value of {key} is {value}")
# Out:
# Value of name is Innocito
# Value of age is 25
# Value of city is Vizag

# %%
company = {"name": "Innocito", "age": 25, "city": "Vizag"}
for key, _ in company.items():
  print(f"Value of {key}")
# Out:
# Value of name
# Value of age
# Value of city
